# %% [markdown]
# ## **PyLadies Tokyo Meetup #27 すうがくはじめの一歩**
# ### **〜Jupyter Notebook入門 ハンズオン〜**

# %% [markdown]
# ### **アジェンダ**
# - JupyterNotbookについて
#     1. JupyterNotebookとは
#     2. JupyterNotebookの操作方法
#     3. 小ネタ
#     4. JupyterNotebookでPythonプログラムを書いてみよう
# - 数値計算ライブラリの紹介
#     1. Pandas
#     2. Numpy
#     3. Matplotlib
#     4. Sympy

# %% [markdown]
# ハンズオンに入る前に以下のGitレポジトリをご自分のローカル環境にgit clone(又はDL)してください
# https://github.com/chanmitsu55/python-math-nyumon
# ※本ノートブックと、ハンズオンで使うデータが入ってます。

# %% [markdown]
# ### **JupyterNotbookについて**
# ### 1.  JupyterNotebookとは
# - WebブラウザからPythonのプログラムを実行することのできる対話型実行ツールです。
# - 「セル」と呼ばれるこの枠内にはPythonプログラムだけでなく、Markdown形式でメモも書けます。
# - 以下のコマンドをコンソール画面から打ってJupyterNotebookを立ち上げてみましょう。
#   `$ jupyter notebook`
# ---
# _※まだJupyterNotebookがインストールできていない方は以下のコマンドでインストールしてください_
#
#  　`$ pip(or conda) install jupyter`

# %% [markdown]
# ### 2. JupyterNotebookの操作方法
# - 最低限、以下の操作を覚えれば快適なJyupyter生活が送れます😊
#     - セルを実行する(画面上部にある「▶|」のボタンでも可)
#         - `shift + Enter`
#     - セル内のモードを`コードモード`又は`Markdownモード`に切り替える
#     (画面上部にあるプルダウンからでも選択可)
#         - `esc+Y`：コードモード
#         - `esc+M`：マークダウンモード
#     - セルを挿入する(画面上部の左側にある「+」ボタンでも可)
#         - `esc+A`：セルを上に挿入する
#         - `esc+B`：セルを下に挿入する
#     - セルを削除する(画面上部にある「Edit」を押して「Delete Cells」を選択するのでも可)
#         - `esc+DD`：セルを削除する

# %% [markdown]
# ### 3. 小ネタ①
# - JupyterNotebookのテーマを変えたい場合
#     - シンプルな最初のUIでも全く問題ないのですが、色々テーマを変えると気分も上がるのでおすすめです。
#     - コンソール上から`jt -l`と打つとテーマ一覧が表示されるのでそこから気に入ったものを選びます。
#     ```
#     $ jt -l
#      Available Themes:
#        chesterish
#        grade3
#        monokai
#        oceans16
#        onedork
#        solarizedd
#        solarizedl
#     ```
#
#     ```
#     $　jt -t solarizedl -T -N
#     # このコマンド後にJupyterNotebookの画面をリロードすると新しいテーマが適用されます。
#     # ちなみに-Tはツールバーの表示、-Nはファイル名とロゴを表示させるオプションです。
#     ```

# %% [markdown]
# ### 3. 小ネタ②
# - Latexみたいに数式を書きたい場合
#     - MarkdownセルにMathJaxで書き込むことでノートブック内で数式も表現できます。
#     - 例として以下を「Markdown」モードで実行してみてください。
# ```
# \begin{equation*}
# P(E)   = {n \choose k} p^k (1-p)^{ n-k}
# \end{equation*}
# ```

# %% [markdown]
# \begin{equation*}
# P(E)   = {n \choose k} p^k (1-p)^{ n-k}
# \end{equation*}

# %% [markdown]
# - 他の数式記法はこちらを参照
# (http://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Typesetting%20Equations.html)

# %% [markdown]
# ### 4. JupyterNotebookでPythonプログラムを書いてみよう
# - ここからは練習を兼ねてprint文から自作関数の実行までやってみたいと思います

# %%
# まずはprint出力
print('shift Enter')
# Out:
# shift Enter

# %%
print('shift Enter')
# Out:
# shift Enter

# %%
# ループ分も同様に
for cnt in range(5):
    print(cnt)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# - 自作関数も実行してみましょう
# - 例としてinput関数を使います

# %%
for cnt in range(5):
    print(cnt)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# input関数とはキーボードに入力したデータを受け付けるための関数です。
# よく使うprint関数は標準出力、input関数はその反対。
inp = input('なんでもよいので入力してください>>> ')
print(inp)

# %% [markdown]
# - これを応用して最後に自作関数を作ってみましょう

# %%
inp = input('なんでも良いので入力するしてください>>>')
print(inp)
# Out:
# なんでも良いので入力するしてください>>>test
# test

# %%
def main():
    num_str = input('好きな数字を入力してください: ')
    num = int(num_str)
    favorite_gundam_series(num)

# 入力した数値をリストに照らし合わせて該当の値を抜き出す関数です
def favorite_gundam_series(num):
    gundam_series = ['機動戦士ガンダム', '機動戦士Zガンダム', '機動戦士ガンダムΖΖ', '機動戦士ガンダム 逆襲のシャア',
                    '機動戦士ガンダムUC', '新機動戦記ガンダムW', '機動戦士ガンダムSEED', '機動戦士ガンダム00']
    idx = int(num) % len(gundam_series)   # 入力値をリストのインデックスに変換する
    print('あなたの好きなガンダムシリーズは')
    print(gundam_series[idx])

if __name__ == '__main__':
    main()

# %% [markdown]
# - ついでなので好きなガンダムシリーズを占う関数も作ってみましょう
# - セル内で必要なライブラリをインポートすれば簡単に実行できます

# %%
def main():
    num_str = input('好きな数字を入力してください：')
    num = int(num_str)
    favorite_gundam_series(num)
    
def favorite_gundam_series(num):
    gundam_series = ['test1', 'test2', 'test3']
    idx = int(num) % len(gundam_series) 
    print('あなたの好きなガンダムシリーズは')
    print(gundam_series[idx])
    
if __name__ =='__main__':
    main()
# Out:
# 好きな数字を入力してください：1
# あなたの好きなガンダムシリーズは
# test2

# %%
from random import randint # ライブラリのインポート
num = randint(0, 7)
favorite_gundam_series(num)
# Out:
# あなたの好きなガンダムシリーズは
# test3

# %% [markdown]
# ### **数値計算ライブラリの紹介**
# - ここからは数値計算でよく使うライブラリを紹介していきます。
# - pythonはライブラリが豊富なので数値計算系といってもかなり多くのライブラリが存在します。
#     - データ処理が得意なPandas
#     - 配列処理ができるNumpy
#     - グラフ描画が得意なMatplotlib
#     - numpyで行える処理に加えて、さらに信号処理や統計といった計算処理ができるScipy
#     - 関数の微分積分をはじめ、式の展開や方程式を解くことができるSympy
# - 本日は上から順にpandas, Numpy, Matplotlibを実際に使っていきましょう！

# %% [markdown]
# ### 1. pandasとは
# - データを容易に扱うためのライブラリ
# - pandasの2つの主要なデータ構造であるSeriesとDataFrameはデータ処理に最適。
# - ここからは実際にtitanic.csvのデータを使って、どんなことができるか見ていきます。
# ※titanic.csvは以下のレポジトリからgit clone又はDLしてください
# https://github.com/chanmitsu55/python-math-nyumon

# %%
# 必要なモジュールをインポート
from pandas import Series, DataFrame
import pandas as pd

# 冒頭でgit cloneした中に入っている「titanic.csv」のローカルパスを記載してください
titanic_df = pd.read_csv('titanic.csv')
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 28            29         1       3
# 29            30         0       3
# ..           ...       ...     ...
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                                Rice, Master. Eugene    male   2.0      4
# 17                        Williams, Mr. Charles Eugene    male   NaN      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 20                                Fynney, Mr. Joseph J    male  35.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                             Emir, Mr. Farred Chehab    male   NaN      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 29                                 Todoroff, Mr. Lalio    male   NaN      0
# ..                                                 ...     ...   ...    ...
# 861                        Giles, Mr. Frederick Edward    male  21.0      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female   NaN      8
# 864                             Gill, Mr. John William    male  24.0      0
# 865                           Bystrom, Mrs. (Karolina)  female  42.0      0
# 866                       Duran y More, Miss. Asuncion  female  27.0      1
# 867               Roebling, Mr. Washington Augustus II    male  31.0      0
# 868                        van Melkebeke, Mr. Philemon    male   NaN      0
# 869                    Johnson, Master. Harold Theodor    male   4.0      1
# 870                                  Balkic, Mr. Cerin    male  26.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 873                        Vander Cruyssen, Mr. Victor    male  47.0      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 876                      Gustafsson, Mr. Alfred Ossian    male  20.0      0
# 877                               Petroff, Mr. Nedelio    male  19.0      0
# 878                                 Laleff, Mr. Kristo    male   NaN      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 881                                 Markun, Mr. Johann    male  33.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 883                      Banfield, Mr. Frederick James    male  28.0      0
# 884                             Sutehall, Mr. Henry Jr    male  25.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket      Fare        Cabin Embarked
# 0        0         A/5 21171    7.2500          NaN        S
# 1        0          PC 17599   71.2833          C85        C
# 2        0  STON/O2. 3101282    7.9250          NaN        S
# 3        0            113803   53.1000         C123        S
# 4        0            373450    8.0500          NaN        S
# 5        0            330877    8.4583          NaN        Q
# 6        0             17463   51.8625          E46        S
# 7        1            349909   21.0750          NaN        S
# 8        2            347742   11.1333          NaN        S
# 9        0            237736   30.0708          NaN        C
# 10       1           PP 9549   16.7000           G6        S
# 11       0            113783   26.5500         C103        S
# 12       0         A/5. 2151    8.0500          NaN        S
# 13       5            347082   31.2750          NaN        S
# 14       0            350406    7.8542          NaN        S
# 15       0            248706   16.0000          NaN        S
# 16       1            382652   29.1250          NaN        Q
# 17       0            244373   13.0000          NaN        S
# 18       0            345763   18.0000          NaN        S
# 19       0              2649    7.2250          NaN        C
# 20       0            239865   26.0000          NaN        S
# 21       0            248698   13.0000          D56        S
# 22       0            330923    8.0292          NaN        Q
# 23       0            113788   35.5000           A6        S
# 24       1            349909   21.0750          NaN        S
# 25       5            347077   31.3875          NaN        S
# 26       0              2631    7.2250          NaN        C
# 27       2             19950  263.0000  C23 C25 C27        S
# 28       0            330959    7.8792          NaN        Q
# 29       0            349216    7.8958          NaN        S
# ..     ...               ...       ...          ...      ...
# 861      0             28134   11.5000          NaN        S
# 862      0             17466   25.9292          D17        S
# 863      2          CA. 2343   69.5500          NaN        S
# 864      0            233866   13.0000          NaN        S
# 865      0            236852   13.0000          NaN        S
# 866      0     SC/PARIS 2149   13.8583          NaN        C
# 867      0          PC 17590   50.4958          A24        S
# 868      0            345777    9.5000          NaN        S
# 869      1            347742   11.1333          NaN        S
# 870      0            349248    7.8958          NaN        S
# 871      1             11751   52.5542          D35        S
# 872      0               695    5.0000  B51 B53 B55        S
# 873      0            345765    9.0000          NaN        S
# 874      0         P/PP 3381   24.0000          NaN        C
# 875      0              2667    7.2250          NaN        C
# 876      0              7534    9.8458          NaN        S
# 877      0            349212    7.8958          NaN        S
# 878      0            349217    7.8958          NaN        S
# 879      1             11767   83.1583          C50        C
# 880      1            230433   26.0000          NaN        S
# 881      0            349257    7.8958          NaN        S
# 882      0              7552   10.5167          NaN        S
# 883      0  C.A./SOTON 34068   10.5000          NaN        S
# 884      0   SOTON/OQ 392076    7.0500          NaN        S
# 885      5            382652   29.1250          NaN        Q
# 886      0            211536   13.0000          NaN        S
# 887      0            112053   30.0000          B42        S
# 888      2        W./C. 6607   23.4500          NaN        S
# 889      0            111369   30.0000         C148        C
# 890      0            370376    7.7500          NaN        Q
#
# [891 rows x 12 columns]

# %%
# 全部表示する必要がなく、どんなデータ構造なのかを知りたいだけであればhead関数を用いる
titanic_df.head(5) # 最初の5行のみ
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#データのサイズを確認
print('titanic data shape:', titanic_df.shape) # (行, 列)の形式で出力
# Out:
# titanic data shape: (891, 12)

# %%
# 「Age(年齢)」の各統計値を求めてみる
titanic_df.Age.describe() #meanは中央値、stdは標準偏差
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
# 列（カラム）の名前を調べる.columnsでわかります。
titanic_df.columns # .columnsを用いる
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# 特定の列だけ抜き出す
titanic_df['Name'].head(5)
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
# 特定のカラムで新しいDataFrameを作る
DataFrame(titanic_df,columns=['Survived','Sex','Age']).head(5)
# Out:
#    Survived     Sex   Age
# 0         0    male  22.0
# 1         1  female  38.0
# 2         1  female  26.0
# 3         1  female  35.0
# 4         0    male  35.0

# %%
# null値がどれ位含まれているか確かめる
# データの前処理で使われる
nulls = pd.DataFrame(titanic_df.isnull().sum().sort_values(ascending=False)) #nullが何個あるか算出
nulls.columns = ['Null Counts'] # 列に「Null Counts」という名前をつける
nulls.index.name = 'Features'   # indexに「Features」という名前をつける
nulls
# Out:
#              Null Counts
# Features
# Cabin                687
# Age                  177
# Embarked               2
# Fare                   0
# Ticket                 0
# Parch                  0
# SibSp                  0
# Sex                    0
# Name                   0
# Pclass                 0
# Survived               0
# PassengerId            0

# %% [markdown]
# ### 2. Numpyとは
# - 多次元の配列を扱うためのライブラリ
# - ndarrayというデータ型を扱う

# %%
import numpy as np

# loadtxt関数でデータを読み込む
# reactions.txtは時間をミリ秒単位で読み込んだデータ
reactions_in_ms = np.loadtxt('reactions.txt')
reactions_in_ms
# Out:
# array([ 664.,  481.,  511.,  612.,  526.,  498.,  441.,  447.,  685.,
#         477.,  525.,  686.,  685.,  485.,  525.,  704.,  631.,  464.,
#         576.,  514.,  516.,  624.,  522.,  586.,  528.,  479.,  491.,
#         588.,  526.,  551.,  454.,  450.,  454.,  613.,  686.,  751.,
#         671.,  489.,  672.,  456.,  595.,  515.,  527.,  467.,  608.,
#         630.,  530.,  494.,  595.,  566.,  552.,  770.,  479.,  513.,
#         566.,  663.,  562.,  475.,  610.,  543.,  519.,  621.,  634.,
#         542.,  754.,  615.,  480.,  791.,  796.,  663.,  501.,  504.,
#         507.,  456.,  586.,  476.,  538.,  554.,  628.,  719.,  527.,
#         505.,  468.,  577.,  469.,  593.,  521.,  461.,  515.,  621.,
#         495.,  516.,  629.,  464.,  547.,  591.,  551.,  689.,  498.,
#         475.,  527.,  522.,  558.,  580.,  623.,  616.,  500.,  478.,
#         487.,  547.,  500.,  454.,  575.,  576.,  540.,  514.,  614.,
#         587.,  505.,  450.,  486.,  494.,  499.,  571.,  618.,  478.,
#         454.,  563.,  503.,  493.,  457.,  565.,  471.,  499.,  696.,
#         487.,  474.,  500.,  514.,  632.,  667.,  619.,  476.,  492.,
#         445.,  528.,  585.,  449.,  487.,  652.,  457.,  667.,  459.,
#         732.,  546.,  730.,  623.,  474.,  502.,  508.,  617.,  710.,
#         736.,  557.,  621.,  530.,  525.,  487.,  498.,  585.,  522.,
#         556.,  467.,  503.,  744.,  648.,  684.,  496.,  483.,  526.,
#         456.,  510.,  512.,  584.,  692.,  448.,  459.,  557.,  454.,
#         540.,  599.,  523.,  458.,  485.,  574.,  638.,  446.,  485.,
#         564.,  518.,  488.,  653.,  477.,  622.,  487.,  596.,  486.,
#         547.,  518.,  561.,  546.,  558.,  523.,  683.,  492.,  590.,
#         634.,  530.,  786.,  586.,  672.,  508.,  566.,  476.,  632.,
#         491.,  811.,  506.,  601.,  488.,  562.,  635.,  570.,  554.,
#         505.,  503.,  448.,  474.,  549.,  507.,  539.,  649.,  453.,
#         517.,  473.,  757.,  582.,  638.,  486.,  610.,  478.,  465.,
#         581.,  581.,  602.,  645.,  659.,  703.,  560.,  639.,  531.,
#         564.,  651.,  499.,  487.,  513.,  465.,  585.,  526.,  592.,
#         602.,  600.,  482.,  742.,  808.,  532.,  599.,  549.,  629.,
#         478.,  561.,  781.,  461.,  603.,  457.,  626.,  508.,  499.,
#         475.,  511.,  531.,  609.,  546.,  492.,  475.,  477.,  746.,
#         469.,  456.,  603.,  497.,  531.,  598.,  606.,  585.,  491.,
#         442.,  499.,  621.,  645.,  617.,  459.,  692.,  457.,  548.,
#         480.,  523.,  507.,  649.,  557.,  547.,  594.,  488.,  603.,
#         672.,  453.,  464.,  616.,  573.,  524.,  557.,  637.,  507.,
#         450.,  448.,  503.,  526.,  471.,  474.,  658.,  475.,  500.,
#         441.,  556.,  479.,  441.,  762.,  484.,  639.,  510.,  528.,
#         713.,  614.,  495.,  573.,  446.,  524.,  574.,  586.,  586.,
#         519.,  545.,  514.,  648.,  498.,  457.,  474.,  492.,  530.,
#         603.,  526.,  572.,  442.,  544.,  515.,  476.,  555.,  539.,
#         533.,  442.,  623.,  474.,  519.,  462.,  475.,  494.,  588.,
#         550.,  470.,  546.,  752.,  516.,  453.,  590.,  565.,  451.,
#         507.,  516.,  553.,  502.,  458.,  599.,  549.,  503.,  642.,
#         594.,  813.,  578.,  448.,  543.,  718.,  612.,  487.,  691.,
#         448.,  642.,  598.,  591.,  472.,  540.,  614.,  489.,  481.,
#         528.,  506.,  470.,  522.,  492.,  792.,  474.,  553.,  475.,
#         664.,  449.,  673.,  461.,  555.,  687.,  507.,  528.,  608.,
#         525.,  471.,  493.,  630.,  686.,  474.,  499.,  518.,  473.,
#         575.,  507.,  471.,  469.,  481.,  575.,  499.,  551.,  560.,
#         593.,  518.,  592.,  592.,  570.,  446.,  696.,  518.,  518.,
#         718.,  538.,  566.,  473.,  504.,  735.,  462.,  604.,  677.,
#         483.,  520.,  481.,  503.,  490.,  580.,  586.,  650.,  474.,
#         559.,  451.,  658.,  582.,  584.,  478.,  451.,  559.,  462.,
#         670.,  569.,  498.,  605.,  443.,  449.,  522.,  521.,  605.,
#         589.,  516.,  503.,  636.,  513.,  559.,  603.,  515.,  790.,
#         596.,  522.,  510.,  527.,  600.,  576.,  476.,  555.,  577.,
#         465.,  632.,  625.,  489.,  667.,  503.,  495.,  644.,  485.,
#         560.,  632.,  675.,  519.,  579.,  522.,  470.,  476.,  657.,
#         592.,  545.,  593.,  691.,  616.,  457.,  539.,  479.,  707.,
#         585.,  453.,  638.,  588.,  476.,  442.,  843.,  540.,  596.,
#         587.,  452.,  566.,  468.,  523.,  507.,  638.,  586.,  736.,
#         551.,  449.,  507.,  621.,  485.,  594.,  575.,  646.,  627.,
#         459.,  487.,  495.,  505.,  474.,  607.,  570.,  554.,  454.,
#         649.,  467.,  653.,  466.,  442.,  515.,  525.,  798.,  552.,
#         494.,  540.,  520.,  474.,  669.,  498.,  589.,  480.,  552.,
#         521.,  496.,  544.,  611.,  569.,  558.,  484.,  612.,  602.,
#         624.,  797.,  547.,  693.,  520.,  466.,  545.,  402.,  340.,
#         439.,  390.,  390.,  411.,  421.,  420.,  411.,  320.,  422.,
#         384.,  420.,  434.,  320.,  401.,  413.,  397.,  417.,  251.,
#         347.,  419.,  414.,  423.,  358.,  377.,  354.,  406.,  433.,
#         393.,  433.,  433.,  393.,  424.,  423.,  344.,  368.,  421.,
#         404.,  320.,  421.,  430.,  389.,  375.,  436.,  423.,  410.,
#         403.,  379.,  314.,  322.,  394.,  420.,  400.,  407.,  354.,
#         432.,  352.,  389.,  367.,  340.,  362.,  360.,  374.,  406.,
#         424.,  440.,  400.,  412.,  406.,  438.,  370.,  389.,  434.,
#         431.,  433.,  421.,  402.,  434.,  426.,  383.,  433.,  408.,
#         349.,  383.,  405.,  388.,  382.,  397.,  382.,  390.,  426.,
#         421.,  428.,  416.,  365.,  396.,  312.,  407.,  431.,  410.,
#         418.,  391.,  426.,  433.,  375.,  379.,  378.,  414.,  437.,
#         437.,  382.,  414.,  435.,  432.,  398.,  434.,  436.,  428.,
#         412.,  355.,  418.,  356.,  432.,  332.,  392.,  394.,  284.,
#         403.,  341.,  390.,  384.,  343.,  433.,  408.,  423.,  331.,
#         440.,  424.,  434.,  374.,  395.,  414.,  395.,  418.,  391.,
#         388.,  411.,  322.,  383.,  434.,  351.,  389.,  342.,  293.,
#         361.,  434.,  415.,  421.,  438.,  402.,  429.,  395.,  413.,
#         429.,  401.,  420.,  422.,  390.,  367.,  415.,  435.,  432.,
#         407.,  368.,  404.,  438.,  429.,  338.,  429.,  328.,  436.,
#         406.,  388.,  424.,  390.,  365.,  432.,  425.,  405.,  418.,
#         389.,  404.,  427.,  383.,  438.,  414.,  405.,  335.,  395.,
#         376.,  438.,  434.,  382.,  414.,  419.,  371.,  438.,  412.,
#         426.,  394.,  436.,  402.,  362.,  430.,  324.,  394.,  394.,
#         335.,  383.,  435.,  318.,  399.,  413.,  401.,  404.,  397.,
#         438.,  415.,  380.,  433.,  400.,  392.,  387.,  371.,  416.,
#         387.,  412.,  419.,  418.,  423.,  423.,  385.,  387.,  348.,
#         346.,  393.,  376.,  399.,  430.,  437.,  315.,  400.,  430.,
#         429.,  423.,  390.,  295.,  350.,  373.,  344.,  355.,  425.,
#         415.,  424.,  433.,  428.,  401.,  354.,  439.,  408.,  268.,
#         361.,  431.,  437.,  407.,  436.,  334.,  369.,  417.,  337.,
#         432.,  413.,  412.,  425.,  342.,  438.,  420.,  366.,  380.,
#         433.,  400.,  431.,  387.,  394.,  354.,  384.,  432.,  368.,
#         423.,  417.,  412.,  341.,  427.,  390.,  394.,  276.,  408.,
#         400.,  297.,  433.,  380.,  372.,  405.,  417.,  383.,  423.,
#         390.,  347.,  430.,  434.,  398.,  422.,  384.,  420.,  383.,
#         387.,  328.,  435.,  386.,  414.,  405.,  437.,  437.,  436.,
#         410.,  403.,  364.,  370.,  429.,  411.,  382.,  371.,  427.,
#         381.,  315.,  399.,  393.,  380.,  372.,  409.,  306.,  408.,
#         403.,  414.,  425.,  376.,  424.,  440.,  380.,  429.,  422.,
#         314.,  361.,  342.,  395.,  419.,  403.,  382.,  354.,  418.,
#         340.,  357.,  421.,  359.,  385.,  389.,  351.,  314.,  396.,  417.])

# %%
#要素数を表示
print(reactions_in_ms.size)
# Out:
# 1000

# %%
# 先頭から10個の要素を表示
print(reactions_in_ms[:10])
# Out:
# [ 664.  481.  511.  612.  526.  498.  441.  447.  685.  477.]

# %% [markdown]
# - 元々のデータはミリ秒の単位なので、これを秒単位で表したい、とする
# - もしこのデータがリストだったらfor文を使ってループさせないといけないが、array型なので単純に1000で割ればよい
# - ここがarray型の便利なところ。

# %%
reactions_in_sec = reactions_in_ms / 1000 # for文使わなくてイイ！ 全ての要素を一率で割ることができる
print(reactions_in_sec[:10]) # 先頭から10個の要素を表示
# Out:
# [ 0.664  0.481  0.511  0.612  0.526  0.498  0.441  0.447  0.685  0.477]

# %%
f = open('reactions.txt')
data1 = f.readlines()   # ファイル終端まで全て読んだデータを返す
f.close()

print(data1)
lines1 = data1.split('\n') # 改行で区切る(改行文字そのものは戻り値のデータには含まれない)
for line in lines1:
    print(line)
# Out:
# ['6.640000000000000000e+02\n', '4.810000000000000000e+02\n', '5.110000000000000000e+02\n', '6.120000000000000000e+02\n', '5.260000000000000000e+02\n', '4.980000000000000000e+02\n', '4.410000000000000000e+02\n', '4.470000000000000000e+02\n', '6.850000000000000000e+02\n', '4.770000000000000000e+02\n', '5.250000000000000000e+02\n', '6.860000000000000000e+02\n', '6.850000000000000000e+02\n', '4.850000000000000000e+02\n', '5.250000000000000000e+02\n', '7.040000000000000000e+02\n', '6.310000000000000000e+02\n', '4.640000000000000000e+02\n', '5.760000000000000000e+02\n', '5.140000000000000000e+02\n', '5.160000000000000000e+02\n', '6.240000000000000000e+02\n', '5.220000000000000000e+02\n', '5.860000000000000000e+02\n', '5.280000000000000000e+02\n', '4.790000000000000000e+02\n', '4.910000000000000000e+02\n', '5.880000000000000000e+02\n', '5.260000000000000000e+02\n', '5.510000000000000000e+02\n', '4.540000000000000000e+02\n', '4.500000000000000000e+02\n', '4.540000000000000000e+02\n', '6.130000000000000000e+02\n', '6.860000000000000000e+02\n', '7.510000000000000000e+02\n', '6.710000000000000000e+02\n', '4.890000000000000000e+02\n', '6.720000000000000000e+02\n', '4.560000000000000000e+02\n', '5.950000000000000000e+02\n', '5.150000000000000000e+02\n', '5.270000000000000000e+02\n', '4.670000000000000000e+02\n', '6.080000000000000000e+02\n', '6.300000000000000000e+02\n', '5.300000000000000000e+02\n', '4.940000000000000000e+02\n', '5.950000000000000000e+02\n', '5.660000000000000000e+02\n', '5.520000000000000000e+02\n', '7.700000000000000000e+02\n', '4.790000000000000000e+02\n', '5.130000000000000000e+02\n', '5.660000000000000000e+02\n', '6.630000000000000000e+02\n', '5.620000000000000000e+02\n', '4.750000000000000000e+02\n', '6.100000000000000000e+02\n', '5.430000000000000000e+02\n', '5.190000000000000000e+02\n', '6.210000000000000000e+02\n', '6.340000000000000000e+02\n', '5.420000000000000000e+02\n', '7.540000000000000000e+02\n', '6.150000000000000000e+02\n', '4.800000000000000000e+02\n', '7.910000000000000000e+02\n', '7.960000000000000000e+02\n', '6.630000000000000000e+02\n', '5.010000000000000000e+02\n', '5.040000000000000000e+02\n', '5.070000000000000000e+02\n', '4.560000000000000000e+02\n', '5.860000000000000000e+02\n', '4.760000000000000000e+02\n', '5.380000000000000000e+02\n', '5.540000000000000000e+02\n', '6.280000000000000000e+02\n', '7.190000000000000000e+02\n', '5.270000000000000000e+02\n', '5.050000000000000000e+02\n', '4.680000000000000000e+02\n', '5.770000000000000000e+02\n', '4.690000000000000000e+02\n', '5.930000000000000000e+02\n', '5.210000000000000000e+02\n', '4.610000000000000000e+02\n', '5.150000000000000000e+02\n', '6.210000000000000000e+02\n', '4.950000000000000000e+02\n', '5.160000000000000000e+02\n', '6.290000000000000000e+02\n', '4.640000000000000000e+02\n', '5.470000000000000000e+02\n', '5.910000000000000000e+02\n', '5.510000000000000000e+02\n', '6.890000000000000000e+02\n', '4.980000000000000000e+02\n', '4.750000000000000000e+02\n', '5.270000000000000000e+02\n', '5.220000000000000000e+02\n', '5.580000000000000000e+02\n', '5.800000000000000000e+02\n', '6.230000000000000000e+02\n', '6.160000000000000000e+02\n', '5.000000000000000000e+02\n', '4.780000000000000000e+02\n', '4.870000000000000000e+02\n', '5.470000000000000000e+02\n', '5.000000000000000000e+02\n', '4.540000000000000000e+02\n', '5.750000000000000000e+02\n', '5.760000000000000000e+02\n', '5.400000000000000000e+02\n', '5.140000000000000000e+02\n', '6.140000000000000000e+02\n', '5.870000000000000000e+02\n', '5.050000000000000000e+02\n', '4.500000000000000000e+02\n', '4.860000000000000000e+02\n', '4.940000000000000000e+02\n', '4.990000000000000000e+02\n', '5.710000000000000000e+02\n', '6.180000000000000000e+02\n', '4.780000000000000000e+02\n', '4.540000000000000000e+02\n', '5.630000000000000000e+02\n', '5.030000000000000000e+02\n', '4.930000000000000000e+02\n', '4.570000000000000000e+02\n', '5.650000000000000000e+02\n', '4.710000000000000000e+02\n', '4.990000 ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-a920f39d24ec> in <module>()
#       4
#       5 print(data1)
# ----> 6 lines1 = data1.split('\n') # 改行で区切る(改行文字そのものは戻り値のデータには含まれない)
#       7 for line in lines1:
#       8     print(line)
#
# AttributeError: 'list' object has no attribute 'split'

# %%
- 各要素に対して掛け算、足し算、といった演算子を使って一括処理ができる点がNumpyの強力な点です

# %% [markdown]
# - その他にもNumpyは統計処理が得意。
# (ちなみに↓と同じことはpandasのdescribe()関数を用いても同じことができます。)

# %%
print('平均値:', np.mean(reactions_in_sec))
print('中央値:', np.median(reactions_in_sec))
print('標準偏差:', np.std(reactions_in_sec))
print('最小値:', np.min(reactions_in_sec))
print('最大値:', np.max(reactions_in_sec))
# Out:
# 平均値: 0.492834
# 中央値: 0.478
# 標準偏差: 0.101900532109
# 最小値: 0.251
# 最大値: 0.843

# %% [markdown]
# - Tips
# 実際にJupyter Notebookでモジュールをインポートする際は以下のように冒頭部分にまとめて記載するのが個人的にはおすすめです。
# ```
# from pandas import Series, DataFrame
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# %matplotlib inline
# ```

# %% [markdown]
# ### 3. Matplotlibとは
# - グラフ描画のためのライブラリ
# - ここではhome.csvというデータを使います。

# %%
import matplotlib.pyplot as plt  #pyplotというパッケージでグラフ描画を行う
# %matplotlib inline 

pd.set_option("display.max_columns", 100) #現在の値は「pd.options.display.max_columns」で確認できる
pd.set_option("display.max_rows", 50) #現在の値は「pd.options.display.max_rows」で確認できる
home_df = pd.read_csv('home.csv')
home_df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# 11      12          60       RL         85.0    11924   Pave   NaN      IR1
# 12      13          20       RL          NaN    12968   Pave   NaN      IR2
# 13      14          20       RL         91.0    10652   Pave   NaN      IR1
# 14      15          20       RL          NaN    10920   Pave   NaN      IR1
# 15      16          45       RM         51.0     6120   Pave   NaN      Reg
# 16      17          20       RL          NaN    11241   Pave   NaN      IR1
# 17      18          90       RL         72.0    10791   Pave   NaN      Reg
# 18      19          20       RL         66.0    13695   Pave   NaN      Reg
# 19      20          20       RL         70.0     7560   Pave   NaN      Reg
# 20      21          60       RL        101.0    14215   Pave   NaN      IR1
# 21      22          45       RM         57.0     7449   Pave  Grvl      Reg
# 22      23          20       RL         75.0     9742   Pave   NaN      Reg
# 23      24         120       RM         44.0     4224   Pave   NaN      Reg
# 24      25          20       RL          NaN     8246   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1435  1436          20       RL         80.0     8400   Pave   NaN      Reg
# 1436  1437          20       RL         60.0     9000   Pave   NaN      Reg
# 1437  1438          20       RL         96.0    12444   Pave   NaN      Reg
# 1438  1439          20       RM         90.0     7407   Pave   NaN      Reg
# 1439  1440          60       RL         80.0    11584   Pave   NaN      Reg
# 1440  1441          70       RL         79.0    11526   Pave   NaN      IR1
# 1441  1442         120       RM          NaN     4426   Pave   NaN      Reg
# 1442  1443          60       FV         85.0    11003   Pave   NaN      Reg
# 1443  1444          30       RL          NaN     8854   Pave   NaN      Reg
# 1444  1445          20       RL         63.0     8500   Pave   NaN      Reg
# 1445  1446          85       RL         70.0     8400   Pave   NaN      Reg
# 1446  1447          20       RL          NaN    26142   Pave   NaN      IR1
# 1447  1448          60       RL         80.0    10000   Pave   NaN      Reg
# 1448  1449          50       RL         70.0    11767   Pave   NaN      Reg
# 1449  1450         180       RM         21.0     1533   Pave   NaN      Reg
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0            Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1            Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2            Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3            Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4            Lvl    AllPub       FR2       Gtl      NoRidge       Norm
# 5            Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 6            Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 7            Lvl    AllPub    Corner       Gtl       NWAmes       PosN
# 8            Lvl    AllPub    Inside       Gtl      OldTown     Artery
# 9            Lvl    AllPub    Corner       Gtl      BrkSide     Artery
# 10           Lvl    AllPub    Inside       Gtl       Sawyer       Norm
# 11           Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 12           Lvl    AllPub    Inside       Gtl       Sawyer       Norm
# 13           Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 14           Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 15           Lvl    AllPub    Corner       Gtl      BrkSide       Norm
# 16           Lvl    AllPub   CulDSac       Gtl        NAmes       Norm
# 17           Lvl    AllPub    Inside       Gtl       Sawyer       Norm
# 18           Lvl    AllPub    Inside       Gtl      SawyerW       RRAe
# 19           Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 20           Lvl    AllPub    Corner       Gtl      NridgHt       Norm
# 21           Bnk    AllPub    Inside       Gtl       IDOTRR       Norm
# 22           Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 23           Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 24           Lvl    AllPub    Inside       Gtl       Sawyer       Norm
# ...          ...       ...       ...       ...          ...        ...
# 1435         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1436         Lvl    AllPub       FR2       Gtl        NAmes       Norm
# 1437         Lvl    AllPub       FR2       Gtl      NridgHt       Norm
# 1438         Lvl    AllPub    Inside       Gtl      OldTown     Artery
# 1439         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1440         Bnk    AllPub    Inside       Mod      Crawfor       Norm
# 1441         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1442         Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 1443         Lvl    AllPub    Inside       Gtl      BrkSide       Norm
# 1444         Lvl    AllPub       FR2       Gtl      CollgCr       Norm
# 1445         Lvl    AllPub    Inside       Gtl       Sawyer       Norm
# 1446         Lvl    AllPub   CulDSac       Gtl      Mitchel       Norm
# 1447         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1448         Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 1449         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 1450         Lvl    AllPub       FR2       Gtl        NAmes       Norm
# 1451         Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 1452         Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 1453         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 1454         Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 1455         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1456         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1458         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1459         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0          Norm     1Fam     2Story            7            5       2003
# 1          Norm     1Fam     1Story            6            8       1976
# 2          Norm     1Fam     2Story            7            5       2001
# 3          Norm     1Fam     2Story            7            5       1915
# 4          Norm     1Fam     2Story            8            5       2000
# 5          Norm     1Fam     1.5Fin            5            5       1993
# 6          Norm     1Fam     1Story            8            5       2004
# 7          Norm     1Fam     2Story            7            6       1973
# 8          Norm     1Fam     1.5Fin            7            5       1931
# 9        Artery   2fmCon     1.5Unf            5            6       1939
# 10         Norm     1Fam     1Story            5            5       1965
# 11         Norm     1Fam     2Story            9            5       2005
# 12         Norm     1Fam     1Story            5            6       1962
# 13         Norm     1Fam     1Story            7            5       2006
# 14         Norm     1Fam     1Story            6            5       1960
# 15         Norm     1Fam     1.5Unf            7            8       1929
# 16         Norm     1Fam     1Story            6            7       1970
# 17         Norm   Duplex     1Story            4            5       1967
# 18         Norm     1Fam     1Story            5            5       2004
# 19         Norm     1Fam     1Story            5            6       1958
# 20         Norm     1Fam     2Story            8            5       2005
# 21         Norm     1Fam     1.5Unf            7            7       1930
# 22         Norm     1Fam     1Story            8            5       2002
# 23         Norm   TwnhsE     1Story            5            7       1976
# 24         Norm     1Fam     1Story            5            8       1968
# ...         ...      ...        ...          ...          ...        ...
# 1435       Norm     1Fam     1Story            6            9       1962
# 1436       Norm     1Fam     1Story            4            6       1971
# 1437       Norm     1Fam     1Story            8            5       2008
# 1438       Norm     1Fam     1Story            6            7       1957
# 1439       Norm     1Fam       SLvl            7            6       1979
# 1440       Norm     1Fam     2.5Fin            6            7       1922
# 1441       Norm   TwnhsE     1Story            6            5       2004
# 1442       Norm     1Fam     2Story           10            5       2008
# 1443       Norm     1Fam     1.5Unf            6            6       1916
# 1444       Norm     1Fam     1Story            7            5       2004
# 1445       Norm     1Fam     SFoyer            6            5       1966
# 1446       Norm     1Fam     1Story            5            7       1962
# 1447       Norm     1Fam     2Story            8            5       1995
# 1448       Norm     1Fam     2Story            4            7       1910
# 1449       Norm    Twnhs     SFoyer            5            7       1970
# 1450       Norm   Duplex     2Story            5            5       1974
# 1451       Norm     1Fam     1Story            8            5       2008
# 1452       Norm   TwnhsE       SLvl            5            5       2005
# 1453       Norm     1Fam     1Story            5            5       2006
# 1454       Norm     1Fam     1Story            7            5       2004
# 1455       Norm     1Fam     2Story            6            5       1999
# 1456       Norm     1Fam     1Story            6            6       1978
# 1457       Norm     1Fam     2Story            7            9       1941
# 1458       Norm     1Fam     1Story            5            6       1950
# 1459       Norm     1Fam     1Story            5            6       1965
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0             2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1             1976     Gable  CompShg     MetalSd     MetalSd       None
# 2             2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3             1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4             2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 5             1995     Gable  CompShg     VinylSd     VinylSd       None
# 6             2005     Gable  CompShg     VinylSd     VinylSd      Stone
# 7             1973     Gable  CompShg     HdBoard     HdBoard      Stone
# 8             1950     Gable  CompShg     BrkFace     Wd Shng       None
# 9             1950     Gable  CompShg     MetalSd     MetalSd       None
# 10            1965       Hip  CompShg     HdBoard     HdBoard       None
# 11            2006       Hip  CompShg     WdShing     Wd Shng      Stone
# 12            1962       Hip  CompShg     HdBoard     Plywood       None
# 13            2007     Gable  CompShg     VinylSd     VinylSd      Stone
# 14            1960       Hip  CompShg     MetalSd     MetalSd    BrkFace
# 15            2001     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 16            1970     Gable  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 17            1967     Gable  CompShg     MetalSd     MetalSd       None
# 18            2004     Gable  CompShg     VinylSd     VinylSd       None
# 19            1965       Hip  CompShg     BrkFace     Plywood       None
# 20            2006     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 21            1950     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 22            2002       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 23            1976     Gable  CompShg     CemntBd     CmentBd       None
# 24            2001     Gable  CompShg     Plywood     Plywood       None
# ...            ...       ...      ...         ...         ...        ...
# 1435          2005     Gable  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 1436          1971     Gable  CompShg     HdBoard     HdBoard       None
# 1437          2008       Hip  CompShg     VinylSd     VinylSd      Stone
# 1438          1996     Gable  CompShg     MetalSd     MetalSd       None
# 1439          1979       Hip  CompShg     HdBoard     HdBoard    BrkFace
# 1440          1994     Gable  CompShg     MetalSd     MetalSd       None
# 1441          2004     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1442          2008     Gable  CompShg     VinylSd     VinylSd      Stone
# 1443          1950     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 1444          2004     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1445          1966     Gable  CompShg     VinylSd     VinylSd       None
# 1446          1962     Gable  CompShg     HdBoard     HdBoard    BrkFace
# 1447          1996     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1448          2000     Gable  CompShg     MetalSd     HdBoard       None
# 1449          1970     Gable  CompShg     CemntBd     CmentBd       None
# 1450          1974     Gable  CompShg     VinylSd     VinylSd       None
# 1451          2009     Gable  CompShg     CemntBd     CmentBd      Stone
# 1452          2005     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1453          2006     Gable  CompShg     VinylSd     VinylSd       None
# 1454          2005     Gable  CompShg     VinylSd     VinylSd       None
# 1455          2000     Gable  CompShg     VinylSd     VinylSd       None
# 1456          1988     Gable  CompShg     Plywood     Plywood      Stone
# 1457          2006     Gable  CompShg     CemntBd     CmentBd       None
# 1458          1996       Hip  CompShg     MetalSd     MetalSd       None
# 1459          1965     Gable  CompShg     HdBoard     HdBoard       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 0          196.0        Gd        TA      PConc       Gd       TA
# 1            0.0        TA        TA     CBlock       Gd       TA
# 2          162.0        Gd        TA      PConc       Gd       TA
# 3            0.0        TA        TA     BrkTil       TA       Gd
# 4          350.0        Gd        TA      PConc       Gd       TA
# 5            0.0        TA        TA       Wood       Gd       TA
# 6          186.0        Gd        TA      PConc       Ex       TA
# 7          240.0        TA        TA     CBlock       Gd       TA
# 8            0.0        TA        TA     BrkTil       TA       TA
# 9            0.0        TA        TA     BrkTil       TA       TA
# 10           0.0        TA        TA     CBlock       TA       TA
# 11         286.0        Ex        TA      PConc       Ex       TA
# 12           0.0        TA        TA     CBlock       TA       TA
# 13         306.0        Gd        TA      PConc       Gd       TA
# 14         212.0        TA        TA     CBlock       TA       TA
# 15           0.0        TA        TA     BrkTil       TA       TA
# 16         180.0        TA        TA     CBlock       TA       TA
# 17           0.0        TA        TA       Slab      NaN      NaN
# 18           0.0        TA        TA      PConc       TA       TA
# 19           0.0        TA        TA     CBlock       TA       TA
# 20         380.0        Gd        TA      PConc       Ex       TA
# 21           0.0        TA        TA      PConc       TA       TA
# 22         281.0        Gd        TA      PConc       Gd       TA
# 23           0.0        TA        TA      PConc       Gd       TA
# 24           0.0        TA        Gd     CBlock       TA       TA
# ...          ...       ...       ...        ...      ...      ...
# 1435       237.0        Gd        Gd     CBlock       TA       TA
# 1436         0.0        TA        TA      PConc       TA       TA
# 1437       426.0        Ex        TA      PConc       Ex       TA
# 1438         0.0        TA        TA     CBlock       TA       TA
# 1439        96.0        TA        TA     CBlock       TA       TA
# 1440         0.0        TA        TA     BrkTil       Ex       TA
# 1441       147.0        Gd        TA      PConc       Gd       TA
# 1442       160.0        Ex        TA      PConc       Ex       TA
# 1443         0.0        TA        TA     BrkTil       TA       TA
# 1444       106.0        Gd        TA      PConc       Gd       TA
# 1445         0.0        TA        TA     CBlock       TA       TA
# 1446       189.0        TA        TA     CBlock       TA       TA
# 1447       438.0        Gd        TA      PConc       Gd       TA
# 1448         0.0        TA        TA     CBlock       Fa       TA
# 1449         0.0        TA        TA     CBlock       Gd       TA
# 1450         0.0        TA        TA     CBlock       Gd       TA
# 1451       194.0        Gd        TA      PConc       Gd       TA
# 1452        80.0        TA        TA      PConc       Gd       TA
# 1453         0.0        TA        TA      PConc       Gd       TA
# 1454         0.0        Gd        TA      PConc       Gd       TA
# 1455         0.0        TA        TA      PConc       Gd       TA
# 1456       119.0        TA        TA     CBlock       Gd       TA
# 1457         0.0        Ex        Gd      Stone       TA       Gd
# 1458         0.0        TA        TA     CBlock       TA       TA
# 1459         0.0        Gd        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 0              No          GLQ         706          Unf           0
# 1              Gd          ALQ         978          Unf           0
# 2              Mn          GLQ         486          Unf           0
# 3              No          ALQ         216          Unf           0
# 4              Av          GLQ         655          Unf           0
# 5              No          GLQ         732          Unf           0
# 6              Av          GLQ        1369          Unf           0
# 7              Mn          ALQ         859          BLQ          32
# 8              No          Unf           0          Unf           0
# 9              No          GLQ         851          Unf           0
# 10             No          Rec         906          Unf           0
# 11             No          GLQ         998          Unf           0
# 12             No          ALQ         737          Unf           0
# 13             Av          Unf           0          Unf           0
# 14             No          BLQ         733          Unf           0
# 15             No          Unf           0          Unf           0
# 16             No          ALQ         578          Unf           0
# 17            NaN          NaN           0          NaN           0
# 18             No          GLQ         646          Unf           0
# 19             No          LwQ         504          Unf           0
# 20             Av          Unf           0          Unf           0
# 21             No          Unf           0          Unf           0
# 22             No          Unf           0          Unf           0
# 23             No          GLQ         840          Unf           0
# 24             Mn          Rec         188          ALQ         668
# ...           ...          ...         ...          ...         ...
# 1435           No          Unf           0          Unf           0
# 1436           No          ALQ         616          Unf           0
# 1437           Av          GLQ        1336          Unf           0
# 1438           No          GLQ         600          Unf           0
# 1439           No          GLQ         315          Rec         110
# 1440           No          Unf           0          Unf           0
# 1441           Av          GLQ         697          Unf           0
# 1442           Av          GLQ         765          Unf           0
# 1443           No          Unf           0          Unf           0
# 1444           Av          Unf           0          Unf           0
# 1445           Gd          LwQ         187          Rec         627
# 1446           No          Rec         593          Unf           0
# 1447           No          GLQ        1079          Unf           0
# 1448           No          Unf           0          Unf           0
# 1449           Av          GLQ         553          Unf           0
# 1450           No          Unf           0          Unf           0
# 1451           No          Unf           0          Unf           0
# 1452           Gd          GLQ         547          Unf           0
# 1453           No          Unf           0          Unf           0
# 1454           No          GLQ         410          Unf           0
# 1455           No          Unf           0          Unf           0
# 1456           No          ALQ         790          Rec         163
# 1457           No          GLQ         275          Unf           0
# 1458           Mn          GLQ          49          Rec        1029
# 1459           No          BLQ         830          LwQ         290
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 0           150          856    GasA        Ex          Y      SBrkr
# 1           284         1262    GasA        Ex          Y      SBrkr
# 2           434          920    GasA        Ex          Y      SBrkr
# 3           540          756    GasA        Gd          Y      SBrkr
# 4           490         1145    GasA        Ex          Y      SBrkr
# 5            64          796    GasA        Ex          Y      SBrkr
# 6           317         1686    GasA        Ex          Y      SBrkr
# 7           216         1107    GasA        Ex          Y      SBrkr
# 8           952          952    GasA        Gd          Y      FuseF
# 9           140          991    GasA        Ex          Y      SBrkr
# 10          134         1040    GasA        Ex          Y      SBrkr
# 11          177         1175    GasA        Ex          Y      SBrkr
# 12          175          912    GasA        TA          Y      SBrkr
# 13         1494         1494    GasA        Ex          Y      SBrkr
# 14          520         1253    GasA        TA          Y      SBrkr
# 15          832          832    GasA        Ex          Y      FuseA
# 16          426         1004    GasA        Ex          Y      SBrkr
# 17            0            0    GasA        TA          Y      SBrkr
# 18          468         1114    GasA        Ex          Y      SBrkr
# 19          525         1029    GasA        TA          Y      SBrkr
# 20         1158         1158    GasA        Ex          Y      SBrkr
# 21          637          637    GasA        Ex          Y      FuseF
# 22         1777         1777    GasA        Ex          Y      SBrkr
# 23          200         1040    GasA        TA          Y      SBrkr
# 24          204         1060    GasA        Ex          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 1435       1319         1319    GasA        TA          Y      SBrkr
# 1436        248          864    GasA        TA          Y      SBrkr
# 1437        596         1932    GasA        Ex          Y      SBrkr
# 1438        312          912    GasA        TA          Y      FuseA
# 1439        114          539    GasA        TA          Y      SBrkr
# 1440        588          588    GasA        Fa          Y      SBrkr
# 1441        151          848    GasA        Ex          Y      SBrkr
# 1442        252         1017    GasA        Ex          Y      SBrkr
# 1443        952          952    Grav        Fa          N      FuseF
# 1444       1422         1422    GasA        Ex          Y      SBrkr
# 1445          0          814    GasA        Gd          Y      SBrkr
# 1446        595         1188    GasA        TA          Y      SBrkr
# 1447        141         1220    GasA        Ex          Y      SBrkr
# 1448        560          560    GasA        Gd          N      SBrkr
# 1449         77          630    GasA        Ex          Y      SBrkr
# 1450        896          896    GasA        TA          Y      SBrkr
# 1451       1573         1573    GasA        Ex          Y      SBrkr
# 1452          0          547    GasA        Gd          Y      SBrkr
# 1453       1140         1140    GasA        Ex          Y      SBrkr
# 1454        811         1221    GasA        Ex          Y      SBrkr
# 1455        953          953    GasA        Ex          Y      SBrkr
# 1456        589         1542    GasA        TA          Y      SBrkr
# 1457        877         1152    GasA        Ex          Y      SBrkr
# 1458          0         1078    GasA        Gd          Y      FuseA
# 1459        136         1256    GasA        Gd          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 0          856       854             0       1710             1             0
# 1         1262         0             0       1262             0             1
# 2          920       866             0       1786             1             0
# 3          961       756             0       1717             1             0
# 4         1145      1053             0       2198             1             0
# 5          796       566             0       1362             1             0
# 6         1694         0             0       1694             1             0
# 7         1107       983             0       2090             1             0
# 8         1022       752             0       1774             0             0
# 9         1077         0             0       1077             1             0
# 10        1040         0             0       1040             1             0
# 11        1182      1142             0       2324             1             0
# 12         912         0             0        912             1             0
# 13        1494         0             0       1494             0             0
# 14        1253         0             0       1253             1             0
# 15         854         0             0        854             0             0
# 16        1004         0             0       1004             1             0
# 17        1296         0             0       1296             0             0
# 18        1114         0             0       1114             1             0
# 19        1339         0             0       1339             0             0
# 20        1158      1218             0       2376             0             0
# 21        1108         0             0       1108             0             0
# 22        1795         0             0       1795             0             0
# 23        1060         0             0       1060             1             0
# 24        1060         0             0       1060             1             0
# ...        ...       ...           ...        ...           ...           ...
# 1435      1537         0             0       1537             1             0
# 1436       864         0             0        864             0             0
# 1437      1932         0             0       1932             1             0
# 1438      1236         0             0       1236             1             0
# 1439      1040       685             0       1725             0             0
# 1440      1423       748           384       2555             0             0
# 1441       848         0             0        848             1             0
# 1442      1026       981             0       2007             1             0
# 1443       952         0             0        952             0             0
# 1444      1422         0             0       1422             0             0
# 1445       913         0             0        913             1             0
# 1446      1188         0             0       1188             0             0
# 1447      1220       870             0       2090             1             0
# 1448       796       550             0       1346             0             0
# 1449       630         0             0        630             1             0
# 1450       896       896             0       1792             0             0
# 1451      1578         0             0       1578             0             0
# 1452      1072         0             0       1072             1             0
# 1453      1140         0             0       1140             0             0
# 1454      1221         0             0       1221             1             0
# 1455       953       694             0       1647             0             0
# 1456      2073         0             0       2073             1             0
# 1457      1188      1152             0       2340             0             0
# 1458      1078         0             0       1078             1             0
# 1459      1256         0             0       1256             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 0            2         1             3             1          Gd
# 1            2         0             3             1          TA
# 2            2         1             3             1          Gd
# 3            1         0             3             1          Gd
# 4            2         1             4             1          Gd
# 5            1         1             1             1          TA
# 6            2         0             3             1          Gd
# 7            2         1             3             1          TA
# 8            2         0             2             2          TA
# 9            1         0             2             2          TA
# 10           1         0             3             1          TA
# 11           3         0             4             1          Ex
# 12           1         0             2             1          TA
# 13           2         0             3             1          Gd
# 14           1         1             2             1          TA
# 15           1         0             2             1          TA
# 16           1         0             2             1          TA
# 17           2         0             2             2          TA
# 18           1         1             3             1          Gd
# 19           1         0             3             1          TA
# 20           3         1             4             1          Gd
# 21           1         0             3             1          Gd
# 22           2         0             3             1          Gd
# 23           1         0             3             1          TA
# 24           1         0             3             1          Gd
# ...        ...       ...           ...           ...         ...
# 1435         1         1             3             1          Gd
# 1436         1         0             3             1          TA
# 1437         2         0             2             1          Ex
# 1438         1         0             2             1          TA
# 1439         2         1             3             1          TA
# 1440         2         0             3             1          TA
# 1441         1         0             1             1          Gd
# 1442         2         1             3             1          Ex
# 1443         1         0             2             1          Fa
# 1444         2         0             3             1          Gd
# 1445         1         0             3             1          TA
# 1446         1         0             3             1          TA
# 1447         2         1             3             1          Gd
# 1448         1         1             2             1          TA
# 1449         1         0             1             1          Ex
# 1450         2         2             4             2          TA
# 1451         2         0             3             1          Ex
# 1452         1         0             2             1          TA
# 1453         1         0             3             1          TA
# 1454         2         0             2             1          Gd
# 1455         2         1             3             1          TA
# 1456         2         0             3             1          TA
# 1457         2         0             4             1          Gd
# 1458         1         0             2             1          Gd
# 1459         1         1             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 0                8        Typ           0         NaN     Attchd       2003.0
# 1                6        Typ           1          TA     Attchd       1976.0
# 2                6        Typ           1          TA     Attchd       2001.0
# 3                7        Typ           1          Gd     Detchd       1998.0
# 4                9        Typ           1          TA     Attchd       2000.0
# 5                5        Typ           0         NaN     Attchd       1993.0
# 6                7        Typ           1          Gd     Attchd       2004.0
# 7                7        Typ           2          TA     Attchd       1973.0
# 8                8       Min1           2          TA     Detchd       1931.0
# 9                5        Typ           2          TA     Attchd       1939.0
# 10               5        Typ           0         NaN     Detchd       1965.0
# 11              11        Typ           2          Gd    BuiltIn       2005.0
# 12               4        Typ           0         NaN     Detchd       1962.0
# 13               7        Typ           1          Gd     Attchd       2006.0
# 14               5        Typ           1          Fa     Attchd       1960.0
# 15               5        Typ           0         NaN     Detchd       1991.0
# 16               5        Typ           1          TA     Attchd       1970.0
# 17               6        Typ           0         NaN    CarPort       1967.0
# 18               6        Typ           0         NaN     Detchd       2004.0
# 19               6       Min1           0         NaN     Attchd       1958.0
# 20               9        Typ           1          Gd    BuiltIn       2005.0
# 21               6        Typ           1          Gd     Attchd       1930.0
# 22               7        Typ           1          Gd     Attchd       2002.0
# 23               6        Typ           1          TA     Attchd       1976.0
# 24               6        Typ           1          TA     Attchd       1968.0
# ...            ...        ...         ...         ...        ...          ...
# 1435             7        Typ           1          Gd     Attchd       1962.0
# 1436             5        Typ           0         NaN     Detchd       1974.0
# 1437             7        Typ           1          Gd     Attchd       2008.0
# 1438             6        Typ           0         NaN     Attchd       1957.0
# 1439             6        Typ           1          TA     Attchd       1979.0
# 1440            11       Min1           1          Gd     Detchd       1993.0
# 1441             3        Typ           1          TA     Attchd       2004.0
# 1442            10        Typ           1          Ex     Attchd       2008.0
# 1443             4        Typ           1          Gd     Detchd       1916.0
# 1444             7        Typ           0         NaN     Attchd       2004.0
# 1445             6        Typ           0         NaN     Detchd       1990.0
# 1446             6        Typ           0         NaN     Attchd       1962.0
# 1447             8        Typ           1          TA     Attchd       1995.0
# 1448             6       Min2           0         NaN     Detchd       1950.0
# 1449             3        Typ           0         NaN        NaN          NaN
# 1450             8        Typ           0         NaN        NaN          NaN
# 1451             7        Typ           1          Gd     Attchd       2008.0
# 1452             5        Typ           0         NaN    Basment       2005.0
# 1453             6        Typ           0         NaN        NaN          NaN
# 1454             6        Typ           0         NaN     Attchd       2004.0
# 1455             7        Typ           1          TA     Attchd       1999.0
# 1456             7       Min1           2          TA     Attchd       1978.0
# 1457             9        Typ           2          Gd     Attchd       1941.0
# 1458             5        Typ           0         NaN     Attchd       1950.0
# 1459             6        Typ           0         NaN     Attchd       1965.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 0             RFn           2         548         TA         TA          Y
# 1             RFn           2         460         TA         TA          Y
# 2             RFn           2         608         TA         TA          Y
# 3             Unf           3         642         TA         TA          Y
# 4             RFn           3         836         TA         TA          Y
# 5             Unf           2         480         TA         TA          Y
# 6             RFn           2         636         TA         TA          Y
# 7             RFn           2         484         TA         TA          Y
# 8             Unf           2         468         Fa         TA          Y
# 9             RFn           1         205         Gd         TA          Y
# 10            Unf           1         384         TA         TA          Y
# 11            Fin           3         736         TA         TA          Y
# 12            Unf           1         352         TA         TA          Y
# 13            RFn           3         840         TA         TA          Y
# 14            RFn           1         352         TA         TA          Y
# 15            Unf           2         576         TA         TA          Y
# 16            Fin           2         480         TA         TA          Y
# 17            Unf           2         516         TA         TA          Y
# 18            Unf           2         576         TA         TA          Y
# 19            Unf           1         294         TA         TA          Y
# 20            RFn           3         853         TA         TA          Y
# 21            Unf           1         280         TA         TA          N
# 22            RFn           2         534         TA         TA          Y
# 23            Unf           2         572         TA         TA          Y
# 24            Unf           1         270         TA         TA          Y
# ...           ...         ...         ...        ...        ...        ...
# 1435          RFn           2         462         TA         TA          Y
# 1436          Unf           2         528         TA         TA          Y
# 1437          Fin           3         774         TA         TA          Y
# 1438          Unf           2         923         TA         TA          Y
# 1439          RFn           2         550         TA         TA          Y
# 1440          Fin           2         672         TA         TA          Y
# 1441          RFn           2         420         TA         TA          Y
# 1442          Fin           3         812         TA         TA          Y
# 1443          Unf           1         192         Fa         Po          P
# 1444          RFn           2         626         TA         TA          Y
# 1445          Unf           1         240         TA         TA          Y
# 1446          Unf           1         312         TA         TA          P
# 1447          RFn           2         556         TA         TA          Y
# 1448          Unf           1         384         Fa         TA          Y
# 1449          NaN           0           0        NaN        NaN          Y
# 1450          NaN           0           0        NaN        NaN          Y
# 1451          Fin           3         840         TA         TA          Y
# 1452          Fin           2         525         TA         TA          Y
# 1453          NaN           0           0        NaN        NaN          Y
# 1454          RFn           2         400         TA         TA          Y
# 1455          RFn           2         460         TA         TA          Y
# 1456          Unf           2         500         TA         TA          Y
# 1457          RFn           1         252         TA         TA          Y
# 1458          Unf           1         240         TA         TA          Y
# 1459          Fin           1         276         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0              0           61              0          0            0
# 1            298            0              0          0            0
# 2              0           42              0          0            0
# 3              0           35            272          0            0
# 4            192           84              0          0            0
# 5             40           30              0        320            0
# 6            255           57              0          0            0
# 7            235          204            228          0            0
# 8             90            0            205          0            0
# 9              0            4              0          0            0
# 10             0            0              0          0            0
# 11           147           21              0          0            0
# 12           140            0              0          0          176
# 13           160           33              0          0            0
# 14             0          213            176          0            0
# 15            48          112              0          0            0
# 16             0            0              0          0            0
# 17             0            0              0          0            0
# 18             0          102              0          0            0
# 19             0            0              0          0            0
# 20           240          154              0          0            0
# 21             0            0            205          0            0
# 22           171          159              0          0            0
# 23           100          110              0          0            0
# 24           406           90              0          0            0
# ...          ...          ...            ...        ...          ...
# 1435           0           36              0          0            0
# 1436           0            0              0          0            0
# 1437           0           66              0        304            0
# 1438           0          158            158          0            0
# 1439           0           88            216          0            0
# 1440         431            0              0          0            0
# 1441         149            0              0          0            0
# 1442         168           52              0          0            0
# 1443           0           98              0          0           40
# 1444         192           60              0          0            0
# 1445           0            0            252          0            0
# 1446         261           39              0          0            0
# 1447           0           65              0          0            0
# 1448         168           24              0          0            0
# 1449           0            0              0          0            0
# 1450          32           45              0          0            0
# 1451           0           36              0          0            0
# 1452           0           28              0          0            0
# 1453          36           56              0          0            0
# 1454           0          113              0          0            0
# 1455           0           40              0          0            0
# 1456         349            0              0          0            0
# 1457           0           60              0          0            0
# 1458         366            0            112          0            0
# 1459         736           68              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 0            0    NaN    NaN         NaN        0       2    2008       WD
# 1            0    NaN    NaN         NaN        0       5    2007       WD
# 2            0    NaN    NaN         NaN        0       9    2008       WD
# 3            0    NaN    NaN         NaN        0       2    2006       WD
# 4            0    NaN    NaN         NaN        0      12    2008       WD
# 5            0    NaN  MnPrv        Shed      700      10    2009       WD
# 6            0    NaN    NaN         NaN        0       8    2007       WD
# 7            0    NaN    NaN        Shed      350      11    2009       WD
# 8            0    NaN    NaN         NaN        0       4    2008       WD
# 9            0    NaN    NaN         NaN        0       1    2008       WD
# 10           0    NaN    NaN         NaN        0       2    2008       WD
# 11           0    NaN    NaN         NaN        0       7    2006      New
# 12           0    NaN    NaN         NaN        0       9    2008       WD
# 13           0    NaN    NaN         NaN        0       8    2007      New
# 14           0    NaN   GdWo         NaN        0       5    2008       WD
# 15           0    NaN  GdPrv         NaN        0       7    2007       WD
# 16           0    NaN    NaN        Shed      700       3    2010       WD
# 17           0    NaN    NaN        Shed      500      10    2006       WD
# 18           0    NaN    NaN         NaN        0       6    2008       WD
# 19           0    NaN  MnPrv         NaN        0       5    2009      COD
# 20           0    NaN    NaN         NaN        0      11    2006      New
# 21           0    NaN  GdPrv         NaN        0       6    2007       WD
# 22           0    NaN    NaN         NaN        0       9    2008       WD
# 23           0    NaN    NaN         NaN        0       6    2007       WD
# 24           0    NaN  MnPrv         NaN        0       5    2010       WD
# ...        ...    ...    ...         ...      ...     ...     ...      ...
# 1435         0    NaN  GdPrv         NaN        0       7    2008      COD
# 1436         0    NaN   GdWo         NaN        0       5    2007       WD
# 1437         0    NaN    NaN         NaN        0      11    2008      New
# 1438         0    NaN  MnPrv         NaN        0       4    2010       WD
# 1439         0    NaN    NaN         NaN        0      11    2007       WD
# 1440         0    NaN    NaN         NaN        0       9    2008       WD
# 1441         0    NaN    NaN         NaN        0       5    2008       WD
# 1442         0    NaN    NaN         NaN        0       4    2009       WD
# 1443         0    NaN    NaN         NaN        0       5    2009       WD
# 1444         0    NaN    NaN         NaN        0      11    2007       WD
# 1445         0    NaN    NaN         NaN        0       5    2007       WD
# 1446         0    NaN    NaN         NaN        0       4    2010       WD
# 1447         0    NaN    NaN         NaN        0      12    2007       WD
# 1448         0    NaN   GdWo         NaN        0       5    2007       WD
# 1449         0    NaN    NaN         NaN        0       8    2006       WD
# 1450         0    NaN    NaN         NaN        0       9    2009       WD
# 1451         0    NaN    NaN         NaN        0       5    2009      New
# 1452         0    NaN    NaN         NaN        0       5    2006       WD
# 1453         0    NaN    NaN         NaN        0       7    2006       WD
# 1454         0    NaN    NaN         NaN        0      10    2009       WD
# 1455         0    NaN    NaN         NaN        0       8    2007       WD
# 1456         0    NaN  MnPrv         NaN        0       2    2010       WD
# 1457         0    NaN  GdPrv        Shed     2500       5    2010       WD
# 1458         0    NaN    NaN         NaN        0       4    2010       WD
# 1459         0    NaN    NaN         NaN        0       6    2008       WD
#
#      SaleCondition  SalePrice
# 0           Normal     208500
# 1           Normal     181500
# 2           Normal     223500
# 3          Abnorml     140000
# 4           Normal     250000
# 5           Normal     143000
# 6           Normal     307000
# 7           Normal     200000
# 8          Abnorml     129900
# 9           Normal     118000
# 10          Normal     129500
# 11         Partial     345000
# 12          Normal     144000
# 13         Partial     279500
# 14          Normal     157000
# 15          Normal     132000
# 16          Normal     149000
# 17          Normal      90000
# 18          Normal     159000
# 19         Abnorml     139000
# 20         Partial     325300
# 21          Normal     139400
# 22          Normal     230000
# 23          Normal     129900
# 24          Normal     154000
# ...            ...        ...
# 1435       Abnorml     174000
# 1436        Normal     120500
# 1437       Partial     394617
# 1438        Normal     149700
# 1439        Normal     197000
# 1440        Normal     191000
# 1441        Normal     149300
# 1442        Normal     310000
# 1443        Normal     121000
# 1444        Normal     179600
# 1445        Normal     129000
# 1446        Normal     157900
# 1447        Normal     240000
# 1448        Normal     112000
# 1449       Abnorml      92000
# 1450        Normal     136000
# 1451       Partial     287090
# 1452        Normal     145000
# 1453       Abnorml      84500
# 1454        Normal     185000
# 1455        Normal     175000
# 1456        Normal     210000
# 1457        Normal     266500
# 1458        Normal     142125
# 1459        Normal     147500
#
# [1460 rows x 81 columns]

# %%
import matplotlib.pyplot as plt  #pyplotというパッケージでグラフ描画を行う
# %matplotlib inline 

pd.set_option("display.max_columns", 100) #現在の値は「pd.options.display.max_columns」で確認できる
pd.set_option("display.max_rows", 50) #現在の値は「pd.options.display.max_rows」で確認できる
home_df = pd.read_csv('home.csv')

# %%
#データのサイズを確認する
print("home data shape:", home_df.shape)
# Out:
# home data shape: (1460, 81)

# %%
plt.style.use(style='ggplot')
plt.rcParams['figure.figsize'] = (10, 6)

# %%
print("Skew is :", home_df.SalePrice.skew()) #skewは歪度
plt.hist(home_df.SalePrice, color='blue')
# Out:
# Skew is : 1.88287575977
# (array([ 148.,  723.,  373.,  135.,   51.,   19.,    4.,    3.,    2.,    2.]),
#  array([  34900.,  106910.,  178920.,  250930.,  322940.,  394950.,
#          466960.,  538970.,  610980.,  682990.,  755000.]),
#  <a list of 10 Patch objects>)

# %%
target = np.log(home_df.SalePrice) 
print("Skew is :", target.skew())
plt.hist(target, color='blue')
# Out:
# Skew is : 0.121335062205
# (array([   5.,   12.,   54.,  184.,  470.,  400.,  220.,   90.,   19.,    6.]),
#  array([ 10.46024211,  10.7676652 ,  11.07508829,  11.38251138,
#          11.68993448,  11.99735757,  12.30478066,  12.61220375,
#          12.91962684,  13.22704994,  13.53447303]),
#  <a list of 10 Patch objects>)

# %%
### 最後に
- もしGithubアカウントを持っていれば今日のNotebookを公開してみましょう！

# %%
target = np.log(home_df.SalePrice)
print("Skew is :", target.skew())
plt.hist(target, color='blue')
# Out:
# Skew is : 0.121335062205
# (array([   5.,   12.,   54.,  184.,  470.,  400.,  220.,   90.,   19.,    6.]),
#  array([ 10.46024211,  10.7676652 ,  11.07508829,  11.38251138,
#          11.68993448,  11.99735757,  12.30478066,  12.61220375,
#          12.91962684,  13.22704994,  13.53447303]),
#  <a list of 10 Patch objects>)
